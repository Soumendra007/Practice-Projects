# %% [markdown]
# # Project Description

# %% [markdown]
# The dataset describes the chemical properties of glass and involves classifying samples of glass using their chemical properties as one of six classes. The dataset was credited to Vina Spiehler in 1987. The study of classification of types of glass was motivated by criminological investigation. At the scene of the crime, the glass left can be used as evidence...if it is correctly identified!

# %% [markdown]
# The chemical compositions are measured as the weight percent in corresponding oxide.
#
# **Attribute Information-**

# %% [markdown]
# 1.	Id number: 1 to 214
#
# 2.	RI: refractive index
#
# 3.	Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
#
# 4.	Mg: Magnesium
#
# 5.	Al: Aluminum
#
# 6.	Si: Silicon
#
# 7.	K: Potassium
#
# 8.	Ca: Calcium
#
# 9.	Ba: Barium
#
# 10.	Fe: Iron
#
# 11.	Type of glass: (class attribute)

# %% [markdown]
# •	1- building_windows_float_processed
#
# •	2- building_windows_non_float_processed
#
# •	3- vehicle_windows_float_processed
#
# •	4- vehicle_windows_non_float_processed (none in this database)
#
# •	5- containers
#
# •	6- tableware
#
# •	7- headlamps

# %% [markdown]
# There are 214 observations in the dataset. The dataset can be divided into window glass (classes 1-4) and non-window glass (classes 5-7).

# %% [markdown]
# **Predict :** Type of glass

# %% [markdown]
# # Dataset Link-

# %% [markdown]
# •	**https://github.com/FlipRoboTechnologies/ML-Datasets/blob/main/Glass%20Identification/Glass%20Identification.csv**

# %% [markdown]
# # Answer:-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv",names=["Id number","RI (Refractive Index)","Na (Sodium)","Mg (Magnesium)","Al (Aluminum)","Si (Silicon)","K (Potassium)","Ca (Calcium)","Ba (Barium)","Fe (Iron)","Type of Glass"])
df
# Out:
#      Id number  RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  \
# 0            1                1.52101        13.64            4.49
# 1            2                1.51761        13.89            3.60
# 2            3                1.51618        13.53            3.55
# 3            4                1.51766        13.21            3.69
# 4            5                1.51742        13.27            3.62
# ..         ...                    ...          ...             ...
# 209        210                1.51623        14.14            0.00
# 210        211                1.51685        14.92            0.00
# 211        212                1.52065        14.36            0.00
# 212        213                1.51651        14.38            0.00
# 213        214                1.51711        14.23            0.00
#
#      Al (Aluminum)  Si (Silicon)  K (Potassium)  Ca (Calcium)  Ba (Barium)  \
# 0             1.10         71.78           0.06          8.75         0.00
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
#Checking every column names present in this dataset 
df.columns.to_list()
# Out:
# ['Id number',
#  'RI (Refractive Index)',
#  'Na (Sodium)',
#  'Mg (Magnesium)',
#  'Al (Aluminum)',
#  'Si (Silicon)',
#  'K (Potassium)',
#  'Ca (Calcium)',
#  'Ba (Barium)',
#  'Fe (Iron)',
#  'Type of Glass']

# %%
#Checking for duplicated row in the Dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Here you can see no duplicate row is present in the dataset.**

# %%
#Checking the dimension of the dataset
df.dtypes
# Out:
# Id number                  int64
# RI (Refractive Index)    float64
# Na (Sodium)              float64
# Mg (Magnesium)           float64
# Al (Aluminum)            float64
# Si (Silicon)             float64
# K (Potassium)            float64
# Ca (Calcium)             float64
# Ba (Barium)              float64
# Fe (Iron)                float64
# Type of Glass              int64
# dtype: object

# %% [markdown]
# **Observation:-**
#
# Here you can see Id number and Type of Glass has only Integer type of data and rest of the columns have Float values.

# %%
#Checking null values for each columns
df.isnull().sum()
# Out:
# Id number                0
# RI (Refractive Index)    0
# Na (Sodium)              0
# Mg (Magnesium)           0
# Al (Aluminum)            0
# Si (Silicon)             0
# K (Potassium)            0
# Ca (Calcium)             0
# Ba (Barium)              0
# Fe (Iron)                0
# Type of Glass            0
# dtype: int64

# %% [markdown]
# **Observation:-**
#
# Here you can see no null value is present.

# %%
#Checking info of df DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id number              214 non-null    int64
#  1   RI (Refractive Index)  214 non-null    float64
#  2   Na (Sodium)            214 non-null    float64
#  3   Mg (Magnesium)         214 non-null    float64
#  4   Al (Aluminum)          214 non-null    float64
#  5   Si (Silicon)           214 non-null    float64
#  6   K (Potassium)          214 non-null    float64
#  7   Ca (Calcium)           214 non-null    float64
#  8   Ba (Barium)            214 non-null    float64
#  9   Fe (Iron)              214 non-null    float64
#  10  Type of Glass          214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %% [markdown]
# **Observation:-**
#
# *1) Here you can see 9 columns contain Float values and 2 columns have the integer values.*
#
# *2) Memory usageis  18.5 KB.*
#
# *3) <class 'pandas.core.frame.DataFrame'> indecates that its the details about the DataFrame.*
#
# *4) Here no null value is present.*

# %%
#Lets visualize null value using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **Here you can see no null value is present.**

# %%
#Checking unique values for each columns
df.nunique().to_frame("Unique value counts")
# Out:
#                        Unique value counts
# Id number                              214
# RI (Refractive Index)                  178
# Na (Sodium)                            142
# Mg (Magnesium)                          94
# Al (Aluminum)                          118
# Si (Silicon)                           133
# K (Potassium)                           65
# Ca (Calcium)                           143
# Ba (Barium)                             34
# Fe (Iron)                               32
# Type of Glass                            6

# %% [markdown]
# **Ovservation:-**
#
# *We can see the difference between our Target Column's unique value with it's all value count is very high,that's mean it's a Classification problem.*

# %%
#Value counts for each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1      1
# 135    1
# 137    1
# 138    1
# 139    1
#       ..
# 75     1
# 76     1
# 77     1
# 78     1
# 214    1
# Name: Id number, Length: 214, dtype: int64
#
#
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI (Refractive Index), Length: 178, dtype: int64
#
#
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na (Sodium), Length: 142, dtype: int64
#
#
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg (Magnesium), Length: 94, dtype: int64
#
#
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Al (Aluminum), Length: 118, dtype: int64
#
#
# 72.86    4
# 72.99    4
# ...

# %% [markdown]
# **Observation:-**
#
# *1) Here you can see no column has blank value.*
#
# *2) Our Target column that is Type of Glass has different counts for different different type of glass that is clearly a class imbalance issue and we have to solve that class imbalance issue with SMOTE in later part.*
#
# *3) Here all columns have numeric datatypes.*

# %%
#Checking description of Dataset
df.describe()
# Out:
#         Id number  RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  \
# count  214.000000             214.000000   214.000000      214.000000
# mean   107.500000               1.518365    13.407850        2.684533
# std     61.920648               0.003037     0.816604        1.442408
# min      1.000000               1.511150    10.730000        0.000000
# 25%     54.250000               1.516522    12.907500        2.115000
# 50%    107.500000               1.517680    13.300000        3.480000
# 75%    160.750000               1.519157    13.825000        3.600000
# max    214.000000               1.533930    17.380000        4.490000
#
#        Al (Aluminum)  Si (Silicon)  K (Potassium)  Ca (Calcium)  Ba (Barium)  \
# count     214.000000    214.000000     214.000000    214.000000   214.000000
# mean        1.444907     72.650935       0.497056      8.956963     0.175047
# std         0.499270      0.774546       0.652192      1.423153     0.497219
# ...

# %% [markdown]
# **Observation:-**
#
# *1) For columns Mg (Magnesium),Si (Silicon),K (Potassium) these column's median(50%) value is greater than mean ,that means these columns values are left skewed.*
#
# *2) For columns RI (Refractive Index),Na (Sodium),Al (Aluminum),Ca (Calcium),Ba (Barium),Fe (Iron) these columns has higher mean value than Midean(50%) that means these column's data has right skewed.*
#
# *3) We can see there is high difference between 75 percentile and Max for Na (Sodium),Mg (Magnesium),Al (Aluminum),K (Potassium),Ca (Calcium),Ba (Barium),Fe (Iron) that means these columns might have outliers.*

# %%
#Setting Id number column as index
df.set_index("Id number",inplace=True)

# %%
df.head(2)
# Out:
#            RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  Al (Aluminum)  \
# Id number
# 1                        1.52101        13.64            4.49           1.10
# 2                        1.51761        13.89            3.60           1.36
#
#            Si (Silicon)  K (Potassium)  Ca (Calcium)  Ba (Barium)  Fe (Iron)  \
# Id number
# 1                 71.78           0.06          8.75          0.0        0.0
# 2                 72.73           0.48          7.83          0.0        0.0
#
#            Type of Glass
# Id number
# 1                      1
# 2                      1

# %% [markdown]
# **I set Id number column as index.**

# %% [markdown]
# # Visualization

# %% [markdown]
# **Univariate Analysis**

# %%
df["Type of Glass"].value_counts()
sns.countplot(x="Type of Glass",data=df)
# Out:
# <Axes: xlabel='Type of Glass', ylabel='count'>

# %% [markdown]
# **Here you can see here six type of Glasses is present and in it 1 and 2 category of glasses counts are high.**

# %% [markdown]
# **Bivariate Analysis**

# %%
sns.lmplot(y="RI (Refractive Index)",x="Type of Glass",data=df,palette="bright")
plt.show()

# %% [markdown]
# **Observation:-**
#
# *1)Here we can see a slight negative relation is formed between RI (Refractive Index) and Type of Glass but that is not strong.*
#
# *2) When RI (Refractive Index) value increases my Target column Type of Glass is decreases towards non-window glass.*

# %%
sns.lmplot(y="Na (Sodium)",x="Type of Glass",data=df)

# %% [markdown]
# **Observation:-**
# *1) Here you can see a positive relation between Na (Sodium) and our Target column Type of Glass but the relation is not strong.*
#
# *2) When RI (Refractive Index) value increases my Target column Type of Glass is increases towards non-window glass.*

# %%
sns.lmplot(y="Mg (Magnesium)",x="Type of Glass",data=df)

# %% [markdown]
# **Observation:-**
#
# *1) Relation between Mg (Magnesium) and Type of Glass is negative but not strong.*
#
# *2) By increasing of Mg (Magnesium) ou Target column(Type of Glass) is decreasing toward Non window glass.*

# %%
sns.lmplot(y="Al (Aluminum)",x="Type of Glass",data=df)

# %% [markdown]
# Observation:-
#
# 1) Relation between Al (Aluminum) and Type of Glass is positive but not strong.
#
# 2) By increasing of Al (Aluminum) value our Target column(Type of Glass) is increasing toward Non window glass.

# %%
sns.lmplot(y="Si (Silicon)",x="Type of Glass",data=df)

# %% [markdown]
# **Observation:-**
#
# Relation between Si (Silicon) and Type of Glass is slightly positive but not strong.
#
# By increasing of Si (Silicon) value our Target column(Type of Glass) is increasing toward Non window glass but it's minimul increasing.

# %%
sns.lmplot(y="K (Potassium)",x="Type of Glass",data=df)

# %% [markdown]
# **Observation:-**
#
# Relation between K (Potassium) and Type of Glass is nutral.
#
# Here no increment and decrement in our Target column(Type of Glass) for K (Potassium) value becasue K (Potassium) value cant make any effect of our Target column(Type of Glass).

# %%
sns.lmplot(y="Ca (Calcium)",x="Type of Glass",data=df)

# %% [markdown]
# **Observation:-**
#
# Relation between Ca (Calcium) and Type of Glass is nutral.

# %%
sns.lmplot(y="Ba (Barium)",x="Type of Glass",data=df)

# %% [markdown]
# **Observation:-**
#
# *1) Relation between Ba (Barium) and Type of Glass is positive but not strong.*
#
# *2) By increasing of Ba (Barium) values Type of Glass value is increases towards 7 that means if we increases Ba (Barium) value the our Glass type would be 7 that means it would be a headlamps glass.*

# %%
sns.lmplot(y="Fe (Iron)",x="Type of Glass",data=df)

# %% [markdown]
# **Observation:-**
#
# 1) Relation between Fe (Iron) and Type of Glass is negative but not strong.
#
# 2) By increasing of Ba Fe (Iron) values Type of Glass value is decreases towards Non window Glass.

# %%
sns.scatterplot(x="RI (Refractive Index)",y="Na (Sodium)",hue="Type of Glass",data=df,palette="bright")
# Out:
# <Axes: xlabel='RI (Refractive Index)', ylabel='Na (Sodium)'>

# %%
sns.scatterplot(x="Mg (Magnesium)",y="Na (Sodium)",hue="Type of Glass",data=df,palette="bright")
# Out:
# <Axes: xlabel='Mg (Magnesium)', ylabel='Na (Sodium)'>

# %% [markdown]
# **Multi-variate Analysis**

# %%
#Creating regplot for each column with our Target column
plt.figure(figsize=(25,20))
p=1
for i in df.columns:
    
    if p<16:
        if i=="Type of Glass":
            continue
        plt.subplot(4,4,p)
        sns.regplot(x="Type of Glass",y=i,data=df)
    p+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Checking all column relationship with Target column (Type of Glass) in a single plot.**

# %%
#Creating pair plot
plt.figure(figsize=(25,20))
sns.pairplot(df,palette="bright",hue="Type of Glass")

# %% [markdown]
# **Observation:-**
#
# *1) RI (Refractive Index) and Ca (Calcium) has strong positive correlation.*
#
# *2) Apart from the RI (Refractive Index) and Ca (Calcium)'s relation all columns relation are nither positive nor negative and we can't judge them because their relation is not in a formation that we can judge.*

# %% [markdown]
# # Checking outliers

# %%
#Creating boxplot to checking
plt.figure(figsize=(25,20))
p=1
for i in df.columns:
    
    if p<16:
        if i=="Type of Glass":
            continue
        plt.subplot(4,3,p)
        sns.boxplot(x=df[i],data=df)
        plt.xlabel(i,fontsize=24)
        
    p+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation:-**
#
# *1) Except Mg (Magnesium) all columns has outliers.*
#
# *2) For Ba (Barium) column I can see there is no box or any whiskers so there is a posibity that all the data points in this columns are very close.So I have to do some more analysis for this column.*

# %%
df.columns
# Out:
# Index(['RI (Refractive Index)', 'Na (Sodium)', 'Mg (Magnesium)',
#        'Al (Aluminum)', 'Si (Silicon)', 'K (Potassium)', 'Ca (Calcium)',
#        'Ba (Barium)', 'Fe (Iron)', 'Type of Glass'],
#       dtype='object')

# %%
#More anlysis for Ba (Barium) column
print(df["Ba (Barium)"].value_counts())
sns.countplot(x="Ba (Barium)",data=df)
# Out:
# 0.00    176
# 0.64      2
# 1.57      2
# 0.09      2
# 1.59      2
# 0.11      2
# 3.15      1
# 0.81      1
# 1.64      1
# 1.06      1
# 0.54      1
# 2.88      1
# 1.38      1
# 1.55      1
# 0.67      1
# 1.71      1
# 0.56      1
# 0.63      1
# 0.53      1
# 0.66      1
# 0.61      1
# 0.27      1
# 0.69      1
# 0.40      1
# 0.14      1
# 0.76      1
# 1.68      1
# 1.63      1
# 1.19      1
# 0.24      1
# 2.20      1
# 0.15      1
# 0.06      1
# 1.67      1
# Name: Ba (Barium), dtype: int64
# <Axes: xlabel='Ba (Barium)', ylabel='count'>

# %% [markdown]
# **Observation:-**
#
# *1) Here you can see there is 176 count values for 0.00 and above 0.00 values are so less and so near by thats why we get no wiskers and boxplot for the Ba (Barium) column.*

# %%
df["Ba (Barium)"].nunique()
# Out:
# 34

# %% [markdown]
# **Also you can see there is only 34 unique values in "Ba (Barium)".**

# %%
sns.lmplot(x="Type of Glass",y="Ba (Barium)",data=df)

# %% [markdown]
# **So there is a positive correlation Ba (Barium) with Type of Glass.**

# %%
df.columns
# Out:
# Index(['RI (Refractive Index)', 'Na (Sodium)', 'Mg (Magnesium)',
#        'Al (Aluminum)', 'Si (Silicon)', 'K (Potassium)', 'Ca (Calcium)',
#        'Ba (Barium)', 'Fe (Iron)', 'Type of Glass'],
#       dtype='object')

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# **Using zscore**

# %%
#Inculding all columns those have outliers except our Target column to a variable named out.
out=df[["RI (Refractive Index)","Na (Sodium)","Al (Aluminum)","Si (Silicon)","K (Potassium)","Ca (Calcium)","Ba (Barium)","Fe (Iron)"]]
from scipy.stats import zscore
z=np.abs(zscore(out))
z
# Out:
#            RI (Refractive Index)  Na (Sodium)  Al (Aluminum)  Si (Silicon)  \
# Id number
# 1                       0.872868     0.284953       0.692442      1.127082
# 2                       0.249333     0.591817       0.170460      0.102319
# 3                       0.721318     0.149933       0.190912      0.438787
# 4                       0.232831     0.242853       0.310994      0.052974
# 5                       0.312045     0.169205       0.411375      0.555256
# ...                          ...          ...            ...           ...
# 210                     0.704815     0.898681       2.881125      0.052974
# 211                     0.500178     1.856097       1.094342      0.529374
# 212                     0.754046     1.168721       1.154570      0.995252
# 213                     0.612399     1.193270       0.993960      1.241133
# 214                     0.414363     1.009152       1.275028      0.917606
#
# ...

# %%
#Locating outliers location
np.where(z>3)
# Out:
# (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#         131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#         188, 189, 201, 201, 203, 207, 213], dtype=int64),
#  array([5, 0, 1, 3, 5, 6, 0, 3, 5, 5, 5, 0, 5, 5, 7, 7, 2, 3, 6, 2, 4, 2,
#         4, 7, 1, 3, 3, 6, 3, 4, 6, 6, 6], dtype=int64))

# %%
#Finding outliers location by giving their location
z.iloc[105,5]
# Out:
# 3.01659640155971

# %% [markdown]
# # Creating outliers free Dataset

# %%
new_df=df[(z<3).all(axis=1)]
new_df.shape
# Out:
# (194, 10)

# %%
print("Old DataFrame",df.shape[0])
print("New DataFrame",new_df.shape[0])
# Out:
# Old DataFrame 214
# New DataFrame 194

# %% [markdown]
# **Observation:-**
#
# *1) Here you can see 20 rows has been deleted due to outliers.*

# %%
#Calculating Data lost percentage after using zscore and  removeing outliers
print("Data lost parcentage:-",((df.shape[0]-new_df.shape[0])/df.shape[0])*100)
# Out:
# Data lost parcentage:- 9.345794392523365

# %% [markdown]
# **So we lost 20 rows from our Dataset due to outliers.** Lets use IQR method to detect outliers and lets see much data we lost after getting a outliers free dataset using IQR method.

# %% [markdown]
# **Remove outliers using IQR method**

# %%
#Q3
Q3=out.quantile(.75)

# %%
#Q1
Q1=out.quantile(.25)

# %%
#IQR
IQR=Q3-Q1
new_df1=df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]

# %%
print("Old DataFrame",df.shape[0])
print("New DataFrame",new_df1.shape[0])
# Out:
# Old DataFrame 214
# New DataFrame 136

# %% [markdown]
# **Here you can see we lost 78 rows out of 214 for outliers that's a huge dataloss.**

# %%
print("Data lost parcentage:-",((df.shape[0]-new_df1.shape[0])/df.shape[0])*100)
# Out:
# Data lost parcentage:- 36.44859813084112

# %% [markdown]
# **So you can clearly see in IQR method I lost too much data.So I will stick to my outliers free dataset that is new_df.**

# %%
new_df.head(2)
# Out:
#            RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  Al (Aluminum)  \
# Id number
# 1                        1.52101        13.64            4.49           1.10
# 2                        1.51761        13.89            3.60           1.36
#
#            Si (Silicon)  K (Potassium)  Ca (Calcium)  Ba (Barium)  Fe (Iron)  \
# Id number
# 1                 71.78           0.06          8.75          0.0        0.0
# 2                 72.73           0.48          7.83          0.0        0.0
#
#            Type of Glass
# Id number
# 1                      1
# 2                      1

# %%
#Reseting index
new_df.reset_index(inplace=True)

# %%
new_df.head(1)
# Out:
#    Id number  RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  \
# 0          1                1.52101        13.64            4.49
#
#    Al (Aluminum)  Si (Silicon)  K (Potassium)  Ca (Calcium)  Ba (Barium)  \
# 0            1.1         71.78           0.06          8.75          0.0
#
#    Fe (Iron)  Type of Glass
# 0        0.0              1

# %% [markdown]
# **Here you can see I reset the index and  I dont need "Id number" column,it's no use for our analysis so I am gonna drop this column permanently.**

# %%
#Dropping "Id number" column
new_df.drop("Id number",axis=1,inplace=True)

# %%
new_df.head(1)
# Out:
#    RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  Al (Aluminum)  \
# 0                1.52101        13.64            4.49            1.1
#
#    Si (Silicon)  K (Potassium)  Ca (Calcium)  Ba (Barium)  Fe (Iron)  \
# 0         71.78           0.06          8.75          0.0        0.0
#
#    Type of Glass
# 0              1

# %% [markdown]
# **You can see Id number column is deleted.**

# %% [markdown]
# # Checking data distribution for each column

# %%
plt .figure(figsize=(25,20))
plot=1

for i in new_df.columns:
    if plot<14:
        plt.subplot(4,3,plot)
        sns.distplot(new_df[i])
        plt.xlabel(i,fontsize=18)
        
    plot+=1
    
plt.show()
plt.tight_layout()

# %% [markdown]
# **Observation:-**
#
# *Here we can see all columns are in almost normally distributed but RI (Refractive Index),Na (Sodium) and Ca (Calcium) is little bit right skewed and Mg (Magnesium) is little bit left skewed.*

# %% [markdown]
# # Checking Skewness

# %%
new_df.skew().to_frame("Skewness value")
# Out:
#                        Skewness value
# RI (Refractive Index)        0.952733
# Na (Sodium)                  0.371482
# Mg (Magnesium)              -1.528849
# Al (Aluminum)                0.658259
# Si (Silicon)                -0.425450
# K (Potassium)                0.303175
# Ca (Calcium)                 1.077962
# Ba (Barium)                  3.188587
# Fe (Iron)                    1.486479
# Type of Glass                1.284007

# %% [markdown]
# **Observation:-**
#
# *1) Our acceptable range for skewness value is +0.5 to -0.5.So here you can see RI (Refractive Index),Mg (Magnesium),Al (Aluminum),Ca (Calcium),Ba (Barium),Fe (Iron) these columns are not falling under the acceptable range so we have to reduce these column's skewness values.*
#
# *2) For Type of Glass column I can ignore it's skewness because it's our Target column.*

# %% [markdown]
# # Reduceing skewness

# %%
#Trying to reduce skewness using cube root method
a=new_df["RI (Refractive Index)"]
b=new_df["Mg (Magnesium)"]
c=new_df["Al (Aluminum)"]
d=new_df["Ca (Calcium)"]
e=new_df["Ba (Barium)"]
f=new_df["Fe (Iron)"]

a=np.cbrt(a)
b=np.cbrt(b)
c=np.cbrt(c)
d=np.cbrt(d)
e=np.cbrt(e)
f=np.cbrt(f)

print("RI (Refractive Index) skewness:",a.skew())
print("Mg (Magnesium):",b.skew())
print("Al (Aluminum):",c.skew())
print("Ca (Calcium):",d.skew())
print("Ba (Barium):",e.skew())
print("Fe (Iron):",f.skew())
# Out:
# RI (Refractive Index) skewness: 0.9480448314348535
# Mg (Magnesium): -1.8990501234610349
# Al (Aluminum): -0.3749777789577748
# Ca (Calcium): 0.6119139878360943
# Ba (Barium): 2.2075937312208755
# Fe (Iron): 0.8831660954818821

# %% [markdown]
# **Observation**
#
# *So we can see Al (Aluminum) column's skewness is reduced using cbrt() method so I will use cube root method to Al (Aluminum) column to reducing it's skewness.Lets see:.*

# %%
#Reducing skewness for Al (Aluminum) column using cube root method
new_df["Al (Aluminum)"]=np.cbrt(new_df["Al (Aluminum)"])

# %%
#Checking skewness again
new_df.skew()
# Out:
# RI (Refractive Index)    0.952733
# Na (Sodium)              0.371482
# Mg (Magnesium)          -1.528849
# Al (Aluminum)           -0.374978
# Si (Silicon)            -0.425450
# K (Potassium)            0.303175
# Ca (Calcium)             1.077962
# Ba (Barium)              3.188587
# Fe (Iron)                1.486479
# Type of Glass            1.284007
# dtype: float64

# %% [markdown]
# **You can see Al (Aluminum) column skewness is reduced but RI (Refractive Index),Mg (Magnesium),Ca (Calcium),Ba (Barium),Fe (Iron) these columns are still not in acceptable range.**

# %%
new_df.isnull().sum()
# Out:
# RI (Refractive Index)    0
# Na (Sodium)              0
# Mg (Magnesium)           0
# Al (Aluminum)            0
# Si (Silicon)             0
# K (Potassium)            0
# Ca (Calcium)             0
# Ba (Barium)              0
# Fe (Iron)                0
# Type of Glass            0
# dtype: int64

# %%
#Trying to reduce skewness using log function +1

a=new_df["RI (Refractive Index)"]
b=new_df["Mg (Magnesium)"]
d=new_df["Ca (Calcium)"]
e=new_df["Ba (Barium)"]
f=new_df["Fe (Iron)"]

a=np.log1p(a)
b=np.log1p(b)
d=np.log1p(d)
e=np.log1p(e)
f=np.log1p(f)

print("RI (Refractive Index) skewness:",a.skew())
print("Mg (Magnesium):",b.skew())
print("Ca (Calcium):",d.skew())
print("Ba (Barium):",e.skew())
print("Fe (Iron):",f.skew())
# Out:
# RI (Refractive Index) skewness: 0.9484921582274499
# Mg (Magnesium): -1.7572171134597134
# Ca (Calcium): 0.42909785500732284
# Ba (Barium): 2.827921260367627
# Fe (Iron): 1.4044430830760077

# %% [markdown]
# **Observation**
#
# *So you can see Ca (Calcium) column's skewness can be reduced by using log1p method.So I will implement log1p on Ca (Calcium) column's permanently.*

# %%
#Reducing skewness of Ca (Calcium) using log function +1
new_df["Ca (Calcium)"]=np.log1p(new_df["Ca (Calcium)"])

# %%
#Checking skewness again
new_df.skew()
# Out:
# RI (Refractive Index)    0.952733
# Na (Sodium)              0.371482
# Mg (Magnesium)          -1.528849
# Al (Aluminum)           -0.374978
# Si (Silicon)            -0.425450
# K (Potassium)            0.303175
# Ca (Calcium)             0.429098
# Ba (Barium)              3.188587
# Fe (Iron)                1.486479
# Type of Glass            1.284007
# dtype: float64

# %% [markdown]
# **You can see Ca (Calcium) column's skewness is also reduced but RI (Refractive Index), Mg (Magnesium),Ba (Barium) and Fe (Iron) is still out of acceptable range.**

# %%
new_df.isnull().sum()
# Out:
# RI (Refractive Index)    0
# Na (Sodium)              0
# Mg (Magnesium)           0
# Al (Aluminum)            0
# Si (Silicon)             0
# K (Potassium)            0
# Ca (Calcium)             0
# Ba (Barium)              0
# Fe (Iron)                0
# Type of Glass            0
# dtype: int64

# %%
#Trying to reducing skewness using log function for these columns those are still out of acceptable range
a=new_df["RI (Refractive Index)"]
b=new_df["Mg (Magnesium)"]
e=new_df["Ba (Barium)"]
f=new_df["Fe (Iron)"]

a=np.log(a)
b=np.log(b)
e=np.log(e)
f=np.log(f)

print("RI (Refractive Index) skewness:",a.skew())
print("Mg (Magnesium):",b.skew())
print("Ba (Barium):",e.skew())
print("Fe (Iron):",f.skew())
# Out:
# RI (Refractive Index) skewness: 0.9457011714542403
# Mg (Magnesium): nan
# Ba (Barium): nan
# Fe (Iron): nan

# %% [markdown]
# **You can see if I try log transformation on those column it will not work and also 3 columns have NaN as skewness value so log() will not work on these columns.So I will use PowerTransformer on these columns lets see:**

# %%
#using PowerTransformer to reduce the skewness
from sklearn.preprocessing import PowerTransformer

pt=PowerTransformer("yeo-johnson")   #yeo-johnson method works on both positive and Negative method

a=new_df["RI (Refractive Index)"]
b=new_df["Mg (Magnesium)"]
e=new_df["Ba (Barium)"]
f=new_df["Fe (Iron)"]

#Reshaping the columns because power transformar need 2d array instead 1d
a_reshape=a.values.reshape(-1,1)
b_reshape=b.values.reshape(-1,1)
e_reshape=e.values.reshape(-1,1)
f_reshape=f.values.reshape(-1,1)

#Now fitting the Transformer
a_transform=pt.fit_transform(a_reshape)
b_transform=pt.fit_transform(b_reshape)
e_transform=pt.fit_transform(e_reshape)
f_transform=pt.fit_transform(f_reshape)

#Convert the transformed array back to the DataFrame
a=pd.DataFrame(a_transform)
b=pd.DataFrame(b_transform)
e=pd.DataFrame(e_transform)
f=pd.DataFrame(f_transform)

print("RI (Refractive Index) skewness:",a.skew())
print("Mg (Magnesium):",b.skew())
print("Ba (Barium):",e.skew())
print("Fe (Iron):",f.skew())
# Out:
# RI (Refractive Index) skewness: 0    0.0
# dtype: float64
# Mg (Magnesium): 0   -1.026009
# dtype: float64
# Ba (Barium): 0    1.971225
# dtype: float64
# Fe (Iron): 0    0.858856
# dtype: float64

# %% [markdown]
# **So here you can see if I use PowerTransformer in RI (Refractive Index) column then it's skewness value will reduce so I will implement PowerTransformer on RI (Refractive Index).Lets see:**

# %%
#using PowerTransformer to reduce the skewness of RI (Refractive Index) skewness
from sklearn.preprocessing import PowerTransformer

pt=PowerTransformer("yeo-johnson")   #yeo-johnson method works on both positive and Negative method

RI_reshape=new_df["RI (Refractive Index)"].values.reshape(-1,1)

#Now fitting the Transformer
RI_transform=pt.fit_transform(RI_reshape)

#Converting transformed array back to the DataFrame
new_df["RI (Refractive Index)"]=pd.DataFrame(RI_transform)

# %%
#Checking the skewness again
new_df.skew()
# Out:
# RI (Refractive Index)    0.000000
# Na (Sodium)              0.371482
# Mg (Magnesium)          -1.528849
# Al (Aluminum)           -0.374978
# Si (Silicon)            -0.425450
# K (Potassium)            0.303175
# Ca (Calcium)             0.429098
# Ba (Barium)              3.188587
# Fe (Iron)                1.486479
# Type of Glass            1.284007
# dtype: float64

# %% [markdown]
# **Observation:-**
#
# *1) Here you can see RI (Refractive Index) column also in acceptable skewness value range.*
#
# *2) Mg (Magnesium),Ba (Barium) and Fe (Iron) still out of our acceptable skewness range so I would try boxcox for Ba (Barium) and Fe (Iron) and after that also if still these column's skewness will not reduced then I have to consider that this skewness values are their threshold skewness value*
#
# *3) We can not apply boxcox on Mg (Magnesium) column because it has negative skewness value and for that reason I dont have any other method left to use on this column.So I have to consider for Mg (Magnesium) column this -1.528849 skewness value is it's threshold and I have to accept it.*

# %%
new_df.isnull().sum()
# Out:
# RI (Refractive Index)    0
# Na (Sodium)              0
# Mg (Magnesium)           0
# Al (Aluminum)            0
# Si (Silicon)             0
# K (Potassium)            0
# Ca (Calcium)             0
# Ba (Barium)              0
# Fe (Iron)                0
# Type of Glass            0
# dtype: int64

# %% [markdown]
# **Here you can see that after appilying PowerTransformar on RI (Refractive Index) there are some Null values appear on that column.**

# %%
#Appliing boxcox to Ba (Barium) 
from scipy.stats import boxcox
e=new_df["Ba (Barium)"]

e=boxcox(e)

print("Ba (Barium):",e.skew())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 5
#       2 from scipy.stats import boxcox
#       3 e=new_df["Ba (Barium)"]
# ----> 5 e=boxcox(e)
#       7 print("Ba (Barium):",e.skew())
#
# File ~\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1102, in boxcox(x, lmbda, alpha, optimizer)
#    1099     raise ValueError("Data must not be constant.")
#    1101 if np.any(x <= 0):
# -> 1102     raise ValueError("Data must be positive.")
#    1104 # If lmbda=None, find the lmbda that maximizes the log-likelihood function.
#    1105 lmax = boxcox_normmax(x, method='mle', optimizer=optimizer)
#
# ValueError: Data must be positive.

# %%
#Appliing boxcox to Fe (Iron)
from scipy.stats import boxcox
f=new_df["Fe (Iron)"]

f=boxcox(f)

print("Fe (Iron):",f.skew())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[139], line 5
#       2 from scipy.stats import boxcox
#       3 f=new_df["Fe (Iron)"]
# ----> 5 f=boxcox(f)
#       7 print("Fe (Iron):",f.skew())
#
# File ~\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1102, in boxcox(x, lmbda, alpha, optimizer)
#    1099     raise ValueError("Data must not be constant.")
#    1101 if np.any(x <= 0):
# -> 1102     raise ValueError("Data must be positive.")
#    1104 # If lmbda=None, find the lmbda that maximizes the log-likelihood function.
#    1105 lmax = boxcox_normmax(x, method='mle', optimizer=optimizer)
#
# ValueError: Data must be positive.

# %% [markdown]
# **Final Observation:-**
#
# *1) Mg (Magnesium) has negative skewness so I can't use boxcox on that to reducing skewness apart from that I used log transform,log function+1,sqrt,cbrt,PowerTransformar but nothing happend so I consider that Mg (Magnesium) column's skewness is threshold for this column and we have to accept it.*
#
# *2) For Ba (Barium) and Fe (Iron) you can see I am getting an error while using boxcox because these column have negative values apart form that I used log transform,log function+1,sqrt,cbrt,PowerTransformar but nothing happend so I have to consider these columns also have their threshold skewness and we have to accept it.

# %% [markdown]
# # Checking Data Distribution Again

# %%
plt .figure(figsize=(25,20),facecolor="r")
plot=1

for i in new_df.columns:
    if plot<14:
        plt.subplot(4,3,plot)
        sns.distplot(new_df[i])
        plt.xlabel(i,fontsize=18)
        
    plot+=1
    
plt.show()
plt.tight_layout()

# %% [markdown]
# **Observation:-**
#
# *You can see all columns are almost normaly distributed.*

# %% [markdown]
# # Correlation between Target column and Independent columns

# %%
new_df.corr()
# Out:
#                        RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  \
# RI (Refractive Index)               1.000000     0.043108        0.052153
# Na (Sodium)                         0.043108     1.000000       -0.487729
# Mg (Magnesium)                      0.052153    -0.487729        1.000000
# Al (Aluminum)                      -0.553362     0.153264       -0.520302
# Si (Silicon)                       -0.603697    -0.234718       -0.377464
# K (Potassium)                      -0.362650    -0.612183        0.482622
# Ca (Calcium)                        0.688599     0.017057       -0.437322
# Ba (Barium)                        -0.198120     0.532000       -0.586581
# Fe (Iron)                          -0.021131    -0.209838        0.134065
# Type of Glass                      -0.172440     0.533025       -0.810321
#
#                        Al (Aluminum)  Si (Silicon)  K (Potassium)  \
# RI (Refractive Index)      -0.553362     -0.603697      -0.362650
# ...

# %%
#Visualizing Correlation between Target variable and Independent variables using heatmap
plt.figure(figsize=(15,9))
sns.heatmap(new_df.corr(),cmap="crest",fmt="0.2f",linewidth="0.2",linecolor="black",annot=True)
plt.xlabel("Features Name",fontsize=14)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %% [markdown]
# **Observation:-**
#
# *You can see Mg (Magnesium) column has strong negative correlation and K (Potassium) and RI (Refractive Index) has negative correlation,apart from that all columns are positively correlated with our Target column.*

# %%
#Checking skewness in ascending order towards our Target column
new_df.corr()["Type of Glass"].sort_values(ascending=True)
# Out:
# Mg (Magnesium)          -0.810321
# K (Potassium)           -0.383499
# Fe (Iron)               -0.202028
# RI (Refractive Index)   -0.172440
# Ca (Calcium)             0.129262
# Si (Silicon)             0.262152
# Na (Sodium)              0.533025
# Al (Aluminum)            0.591653
# Ba (Barium)              0.682768
# Type of Glass            1.000000
# Name: Type of Glass, dtype: float64

# %% [markdown]
# **Here you can see all column skewness is sorted assending order towards our Target column(Type of Glass) where Mg (Magnesium) is Highly negative correlated and Ba (Barium) is nearby Highly positive correlated.**

# %% [markdown]
# # Separating Target column and Features

# %%
#Separating Target and Independent variable
x=new_df.iloc[:,:-1]
y=new_df.iloc[:,-1]

print("Features Dimension",x.shape)
print("Label dimension",y.shape)
# Out:
# Features Dimension (194, 9)
# Label dimension (194,)

# %% [markdown]
# # Feature scalling using StadardScaler

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=pd.DataFrame(ss.fit_transform(x),columns=x.columns)
x
# Out:
#      RI (Refractive Index)  Na (Sodium)  Mg (Magnesium)  Al (Aluminum)  \
# 0                 1.231043     0.332127        1.233397      -0.666678
# 1                -0.179830     0.704398        0.551581      -0.035036
# 2                -0.821136     0.168328        0.513277       0.356287
# 3                -0.179830    -0.308179        0.620529      -0.196550
# 4                -0.308091    -0.218834        0.566903      -0.315529
# ..                     ...          ...             ...            ...
# 189              -0.692875     1.419158       -2.206325       2.397864
# 190              -0.821136     1.076668       -2.206325       2.593556
# 191              -0.564614     2.238153       -2.206325       1.216416
# 192               1.102782     1.404267       -2.206325       1.268927
# 193              -0.692875     1.434048       -2.206325       1.127713
#
#      Si (Silicon)  K (Potassium)  Ca (Calcium)  Ba (Barium)  Fe (Iron)
# ...

# %%
#Finding VIF for each column
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features Name"]=x.columns

# %%
vif
# Out:
#    VIF Values          Features Name
# 0    5.287226  RI (Refractive Index)
# 1   28.773800            Na (Sodium)
# 2   84.438132         Mg (Magnesium)
# 3   10.180842          Al (Aluminum)
# 4   18.512378           Si (Silicon)
# 5   10.309251          K (Potassium)
# 6   60.081297           Ca (Calcium)
# 7    9.588456            Ba (Barium)
# 8    1.070487              Fe (Iron)

# %% [markdown]
# **Observation:-**
#
# *Our acceptable VIF value range is 10 and we can see Na (Sodium),Mg (Magnesium),Al (Aluminum),Si (Silicon),K (Potassium) and Ca (Calcium) columns are above the range So I have to delete that column which have highest VIF value and have to check VIF value again.*

# %%
#Deleting the Mg (Magnesium) which have the hight VIF value(84.43)
x.drop("Mg (Magnesium)",axis=1,inplace=True)

# %%
x.head(2)
# Out:
#    RI (Refractive Index)  Na (Sodium)  Al (Aluminum)  Si (Silicon)  \
# 0               1.231043     0.332127      -0.666678     -1.612464
# 1              -0.179830     0.704398      -0.035036      0.016082
#
#    K (Potassium)  Ca (Calcium)  Ba (Barium)  Fe (Iron)
# 0      -1.319609     -0.028815    -0.346292  -0.603056
# 1       0.172091     -1.046481    -0.346292  -0.603056

# %% [markdown]
# **You can see Mg (Magnesium) is deleted form Independent variable.**

# %%
#Checking for  Multicolinearity(VIF) again
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features Name"]=x.columns

# %%
vif
# Out:
#    VIF Values          Features Name
# 0    5.133976  RI (Refractive Index)
# 1    3.301579            Na (Sodium)
# 2    2.031109          Al (Aluminum)
# 3    2.663144           Si (Silicon)
# 4    3.287141          K (Potassium)
# 5    3.426176           Ca (Calcium)
# 6    2.083065            Ba (Barium)
# 7    1.065317              Fe (Iron)

# %% [markdown]
# **Observation:-**
#
# *Now you can see after deleting the Mg (Magnesium) column all columns VIF values are in acceptable range(below 10), that means Mg (Magnesium) column was the main reason for the multicolinearity.*

# %% [markdown]
# # Over Sampling

# %%
new_df["Type of Glass"].value_counts()
# Out:
# 1    70
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: Type of Glass, dtype: int64

# %% [markdown]
# **Here we can see our Target column has class imbalance issue.I have to use SMOTE to overcome it.**

# %%
#Over sampling the data
# !pip install imblearn
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x1,y1=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    70
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: Type of Glass, dtype: int64

# %%
y1.value_counts()
# Out:
# 1    70
# 2    70
# 3    70
# 5    70
# 6    70
# 7    70
# Name: Type of Glass, dtype: int64

# %% [markdown]
# **Now we can see our Target varable is now equally balanced.**

# %% [markdown]
# # Modeling

# %% [markdown]
# # Finding the best Random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
MaxAcc=0
MaxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
    RFC=RandomForestClassifier()
    RFC.fit(x_train,y_train)
    pred=RFC.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>MaxAcc:
        MaxAcc=acc
        MaxRs=i
        
print("The best accuracy score is",MaxAcc,"at Random State",MaxRs)
# Out:
# The best accuracy score is 0.9682539682539683 at Random State 48

# %% [markdown]
# **So the best accuracy is 0.968253968 at the random State 48.**

# %% [markdown]
# # Creating train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.30,random_state=MaxRs)

# %% [markdown]
# # Classification Algorithms

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix, roc_curve

# %% [markdown]
# **RandomForestClassifier**

# %%
#Checking accuracy for RandomForestClassifier
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
pred_RFC=RFC.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_RFC))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_RFC))
print("Classification Report:-\n",classification_report(y_test,pred_RFC))
# Out:
# Accuracy Score:- 0.9365079365079365
# Confution Matrix:-
#  [[10  1  2  0  0  1]
#  [ 3 16  1  0  0  0]
#  [ 0  0 26  0  0  0]
#  [ 0  0  0 28  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.77      0.71      0.74        14
#            2       0.94      0.80      0.86        20
#            3       0.90      1.00      0.95        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        18
#            7       0.95      1.00      0.98        20
#
#     accuracy                           0.94       126
#    macro avg       0.93      0.92      0.92       126
# weighted avg       0.94      0.94      0.93       126

# %% [markdown]
# **ExtraTreesClassifier**

# %%
#Checking accuracy for ExtraTreesClassifier
ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
pred_ETC=ETC.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_ETC))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_ETC))
print("Classification Report:-\n",classification_report(y_test,pred_ETC))
# Out:
# Accuracy Score:- 0.9603174603174603
# Confution Matrix:-
#  [[12  0  1  0  0  1]
#  [ 3 17  0  0  0  0]
#  [ 0  0 26  0  0  0]
#  [ 0  0  0 28  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.80      0.86      0.83        14
#            2       1.00      0.85      0.92        20
#            3       0.96      1.00      0.98        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        18
#            7       0.95      1.00      0.98        20
#
#     accuracy                           0.96       126
#    macro avg       0.95      0.95      0.95       126
# weighted avg       0.96      0.96      0.96       126

# %% [markdown]
# **AdaBoostClassifier**

# %%
#Checking accuracy for AdaBoostClassifier
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
pred_ABC=ABC.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_ABC))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_ABC))
print("Classification Report:-\n",classification_report(y_test,pred_ABC))
# Out:
# Accuracy Score:- 0.2698412698412698
# Confution Matrix:-
#  [[13  0  0  0  0  1]
#  [20  0  0  0  0  0]
#  [25  0  1  0  0  0]
#  [28  0  0  0  0  0]
#  [ 0  0 18  0  0  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.15      0.93      0.26        14
#            2       0.00      0.00      0.00        20
#            3       0.05      0.04      0.04        26
#            5       0.00      0.00      0.00        28
#            6       0.00      0.00      0.00        18
#            7       0.95      1.00      0.98        20
#
#     accuracy                           0.27       126
#    macro avg       0.19      0.33      0.21       126
# weighted avg       0.18      0.27      0.19       126

# %% [markdown]
# **GradientBoostingClassifier**

# %%
#Checking accuracy for GradientBoostingClassifier
GBC=GradientBoostingClassifier()
GBC.fit(x_train,y_train)
pred_GBC=GBC.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_GBC))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_GBC))
print("Classification Report:-\n",classification_report(y_test,pred_GBC))
# Out:
# Accuracy Score:- 0.9444444444444444
# Confution Matrix:-
#  [[11  1  1  0  0  1]
#  [ 3 17  0  0  0  0]
#  [ 0  1 25  0  0  0]
#  [ 0  0  0 28  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.79      0.79      0.79        14
#            2       0.89      0.85      0.87        20
#            3       0.96      0.96      0.96        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        18
#            7       0.95      1.00      0.98        20
#
#     accuracy                           0.94       126
#    macro avg       0.93      0.93      0.93       126
# weighted avg       0.94      0.94      0.94       126

# %% [markdown]
# **BaggingClassifier**

# %%
#Checking accuracy for BaggingClassifier
BC=BaggingClassifier()
BC.fit(x_train,y_train)
pred_BC=BC.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_BC))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_BC))
print("Classification Report:-\n",classification_report(y_test,pred_BC))
# Out:
# Accuracy Score:- 0.9206349206349206
# Confution Matrix:-
#  [[10  2  1  0  0  1]
#  [ 4 15  1  0  0  0]
#  [ 1  0 25  0  0  0]
#  [ 0  0  0 28  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.67      0.71      0.69        14
#            2       0.88      0.75      0.81        20
#            3       0.93      0.96      0.94        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        18
#            7       0.95      1.00      0.98        20
#
#     accuracy                           0.92       126
#    macro avg       0.90      0.90      0.90       126
# weighted avg       0.92      0.92      0.92       126

# %% [markdown]
# **DecisionTreeClassifier**

# %%
#Checking accuracy for DecisionTreeClassifier
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred_DTC=DTC.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_DTC))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_DTC))
print("Classification Report:-\n",classification_report(y_test,pred_DTC))
# Out:
# Accuracy Score:- 0.9206349206349206
# Confution Matrix:-
#  [[12  1  0  0  0  1]
#  [ 3 15  2  0  0  0]
#  [ 1  2 23  0  0  0]
#  [ 0  0  0 28  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.75      0.86      0.80        14
#            2       0.83      0.75      0.79        20
#            3       0.92      0.88      0.90        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        18
#            7       0.95      1.00      0.98        20
#
#     accuracy                           0.92       126
#    macro avg       0.91      0.92      0.91       126
# weighted avg       0.92      0.92      0.92       126

# %% [markdown]
# **KNeighborsClassifier**

# %%
#Checking accuracy for KNeighborsClassifier
KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
pred_KNN=KNN.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_KNN))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_KNN))
print("Classification Report:-\n",classification_report(y_test,pred_KNN))
# Out:
# Accuracy Score:- 0.9126984126984127
# Confution Matrix:-
#  [[11  1  2  0  0  0]
#  [ 4 14  2  0  0  0]
#  [ 1  1 24  0  0  0]
#  [ 0  0  0 28  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.69      0.79      0.73        14
#            2       0.88      0.70      0.78        20
#            3       0.86      0.92      0.89        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        18
#            7       1.00      1.00      1.00        20
#
#     accuracy                           0.91       126
#    macro avg       0.90      0.90      0.90       126
# weighted avg       0.92      0.91      0.91       126

# %% [markdown]
# **SVC**

# %%
#Checking accuracy for SVC
svc=SVC()
svc.fit(x_train,y_train)
pred_svc=svc.predict(x_test)
print("Accuracy Score:-",accuracy_score(y_test,pred_svc))
print("Confution Matrix:-\n",confusion_matrix(y_test,pred_svc))
print("Classification Report:-\n",classification_report(y_test,pred_svc))
# Out:
# Accuracy Score:- 0.8809523809523809
# Confution Matrix:-
#  [[ 9  3  2  0  0  0]
#  [ 3 14  3  0  0  0]
#  [ 1  3 22  0  0  0]
#  [ 0  0  0 28  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  0  0 20]]
# Classification Report:-
#                precision    recall  f1-score   support
#
#            1       0.69      0.64      0.67        14
#            2       0.70      0.70      0.70        20
#            3       0.81      0.85      0.83        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        18
#            7       1.00      1.00      1.00        20
#
#     accuracy                           0.88       126
#    macro avg       0.87      0.86      0.87       126
# weighted avg       0.88      0.88      0.88       126

# %% [markdown]
# **MultinomialNB**

# %%
#Checking accuracy for MultinomialNB
try:
    MNB=MultinomialNB()
    MNB.fit(x_train,y_train)
    pred_MNB=MNB.predict(x_test)
    print("Accuracy Score:-",accuracy_score(y_test,pred_MNB))
    print("Confution Matrix:-\n",confusion_matrix(y_test,pred_MNB))
    print("Classification Report:-\n",classification_report(y_test,pred_MNB))
except ValueError:
    print("Negative values in data passed to MultinomialNB")
# Out:
# Negative values in data passed to MultinomialNB

# %% [markdown]
# **Observation:-**
#
# *Bases on the accuracy ExtraTreesClassifier is the best model till now but we all now that this is not actual accuracy we have to Cross check it with cross validation.*

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(RFC,x1,y1)
print(score)
print(score.mean())
print("Difference between accuracy score of RandomForestClassifier and cross validation score is:-",(accuracy_score(y_test,pred_RFC)-score.mean())*100)
# Out:
# [0.86904762 0.88095238 0.86904762 0.83333333 0.88095238]
# 0.8666666666666668
# Difference between accuracy score of RandomForestClassifier and cross validation score is:- 6.98412698412697

# %%
score1=cross_val_score(ETC,x1,y1)
print(score1)
print(score1.mean())
print("Difference between accuracy score of ExtraTreeClassifier and cross validation score is:-",(accuracy_score(y_test,pred_ETC)-score1.mean())*100)
# Out:
# [0.85714286 0.85714286 0.83333333 0.85714286 0.89285714]
# 0.8595238095238095
# Difference between accuracy score of ExtraTreeClassifier and cross validation score is:- 10.079365079365088

# %%
score2=cross_val_score(ABC,x1,y1)
print(score2)
print(score2.mean())
print("Difference between accuracy score of AdaBoostClassifier and cross validation score is:-",(accuracy_score(y_test,pred_ABC)-score2.mean())*100)
# Out:
# [0.39285714 0.33333333 0.45238095 0.19047619 0.46428571]
# 0.3666666666666667
# Difference between accuracy score of AdaBoostClassifier and cross validation score is:- -9.682539682539687

# %%
score3=cross_val_score(GBC,x1,y1)
print(score3)
print(score3.mean())
print("Difference between accuracy score of GradientBoostingClassifier and cross validation score is:-",(accuracy_score(y_test,pred_GBC)-score3.mean())*100)
# Out:
# [0.8452381  0.86904762 0.86904762 0.82142857 0.86904762]
# 0.8547619047619047
# Difference between accuracy score of GradientBoostingClassifier and cross validation score is:- 8.96825396825397

# %%
score4=cross_val_score(BC,x1,y1)
print(score4)
print(score4.mean())
print("Difference between accuracy score of BaggingClassifier and cross validation score is:-",(accuracy_score(y_test,pred_BC)-score4.mean())*100)
# Out:
# [0.83333333 0.80952381 0.85714286 0.79761905 0.80952381]
# 0.8214285714285714
# Difference between accuracy score of BaggingClassifier and cross validation score is:- 9.92063492063492

# %%
score5=cross_val_score(DTC,x1,y1)
print(score5)
print(score5.mean())
print("Difference between accuracy score of DecisionTreeClassifier and cross validation score is:-",(accuracy_score(y_test,pred_DTC)-score5.mean())*100)
# Out:
# [0.79761905 0.85714286 0.88095238 0.78571429 0.80952381]
# 0.8261904761904761
# Difference between accuracy score of DecisionTreeClassifier and cross validation score is:- 9.444444444444445

# %%
score6=cross_val_score(KNN,x1,y1)
print(score6)
print(score6.mean())
print("Difference between accuracy score of KNeighborsClassifier and cross validation score is:-",(accuracy_score(y_test,pred_KNN)-score6.mean())*100)
# Out:
# [0.82142857 0.83333333 0.83333333 0.8452381  0.8452381 ]
# 0.8357142857142857
# Difference between accuracy score of KNeighborsClassifier and cross validation score is:- 7.698412698412693

# %%
score7=cross_val_score(svc,x1,y1)
print(score7)
print(score7.mean())
print("Difference between accuracy score of SVC and cross validation score is:-",(accuracy_score(y_test,pred_svc)-score7.mean())*100)
# Out:
# [0.82142857 0.82142857 0.83333333 0.88095238 0.86904762]
# 0.8452380952380952
# Difference between accuracy score of SVC and cross validation score is:- 3.57142857142857

# %% [markdown]
# **Observation:-**
#
# *1) Here you can see from all models SVC has the least difference between it's accuracy and cross_val_score(3.57...) so we can take this model as our best model.*
#
# *2) So we took SVC as our best model.*

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#SVC
from sklearn.model_selection import GridSearchCV
paramiters={"kernel":["linear", "poly", "rbf"],
       "gamma":["scale", "auto"],
       "C":[1.0,.05, .4,2],
       "degree":[1,4,10,20],
       "decision_function_shape":["ovo", "ovr"],
       "random_state":[1,4,10,20]
    
}

# %%
GCV=GridSearchCV(SVC(),paramiters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1.0, 0.05, 0.4, 2],
#                          'decision_function_shape': ['ovo', 'ovr'],
#                          'degree': [1, 4, 10, 20], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf'],
#                          'random_state': [1, 4, 10, 20]})

# %%
GCV.best_params_
# Out:
# {'C': 2,
#  'decision_function_shape': 'ovo',
#  'degree': 1,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'random_state': 1}

# %% [markdown]
# # Final Model

# %%
Final_Model=SVC(C=2,decision_function_shape='ovo',degree=1,gamma='scale',kernel='rbf',random_state=1)
Final_Model.fit(x_train,y_train)
pred=Final_Model.predict(x_test)
acc=accuracy_score(y_test,pred)
print("Accuracy:-",acc*100)
# Out:
# Accuracy:- 90.47619047619048

# %% [markdown]
# **Observation:-**
#
# *1) Earlier SVC had accuracy of 0.8809 means 88.09% but you can see after Hyperparameter tuning it's accuracy is 90.47619047.. it means 90.47%.*
#
# *2) So we can see our model accuracy is increased.*

# %% [markdown]
# # Saving the best model

# %% [markdown]
# **Serialization**

# %%
#Saving best model
import joblib
joblib.dump(Final_Model,"Glass.pkl")
# Out:
# ['Glass.pkl']

# %% [markdown]
# **De-Serialization**

# %%
#Loading the model and try to make prediction with it.
Model=joblib.load("Glass.pkl")

prediction=Model.predict(x_test)
prediction
# Out:
# array([2, 6, 7, 5, 3, 6, 5, 3, 6, 7, 2, 6, 7, 2, 3, 5, 3, 6, 7, 3, 7, 5,
#        7, 2, 6, 6, 1, 5, 3, 5, 2, 3, 2, 5, 6, 1, 6, 2, 3, 3, 3, 5, 2, 5,
#        3, 3, 3, 5, 5, 5, 2, 1, 3, 5, 3, 5, 7, 5, 1, 1, 3, 6, 5, 6, 5, 1,
#        3, 1, 6, 3, 7, 2, 7, 2, 2, 5, 2, 1, 7, 5, 5, 6, 7, 1, 2, 6, 7, 1,
#        5, 3, 7, 2, 6, 5, 1, 6, 7, 2, 5, 1, 1, 5, 5, 2, 1, 5, 7, 3, 3, 3,
#        3, 7, 3, 7, 1, 5, 6, 7, 7, 6, 5, 3, 3, 3, 7, 2], dtype=int64)

# %%
#Comparing orginal data with predicted one
Check=np.array(y_test)
df1=pd.DataFrame()
df1["Prediction"]=prediction
df1["Original"]=Check
df1
# Out:
#      Prediction  Original
# 0             2         2
# 1             6         6
# 2             7         7
# 3             5         5
# 4             3         3
# ..          ...       ...
# 121           3         3
# 122           3         3
# 123           3         3
# 124           7         7
# 125           2         3
#
# [126 rows x 2 columns]

# %% [markdown]
# # User Define Function to predict Glass quality

# %%
def Glass_prediction(a):
    a=a.reshape(1,-1)
    result=Model.predict(a)
    if result==1:
        print("This Glass is used for building_windows_float_processed.")
        
    elif result==2:
        print("This Glass is used for building_windows_non_float_processed.")
        
    elif result==3:
        print("This Glass is used for vehicle_windows_float_processed.")
    
    elif result==4:
        print("This Glass is used for vehicle_windows_non_float_processed.")
        
    elif result==5:
        print("This Glass is used for containers.")
        
    elif result==6:
        print("This Glass is used for tableware.")
        
    else:
        print("This Glass is used for headlamps.")

# %%
#Creating an array as input data to check the Glass quality prediction
input_data=np.array([1.231043,0.332127,-0.666678,-1.612464,-1.319609,-0.028815,-0.346292,-0.603056])

# %%
#Giving our data to our created function to check it can predict  the glass quality or not
Glass_prediction(input_data)
# Out:
# This Glass is used for building_windows_float_processed.

# %% [markdown]
# # ***The End***
